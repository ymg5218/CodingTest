# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node(1)
print(G.nodes())
# Out:
# [1]

# %%
G.add_node('P')
G.add_node('Hi')
print(G.nodes())
# Out:
# [1, 'P', 'Hi']

# %%
G.add_nodes_from([2, 3])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3]

# %%
for node in G.nodes():
    print(node)
# Out:
# 1
# P
# Hi
# 2
# 3

# %%
G.add_nodes_from([3, 4])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]

# %%
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G.add_edge(1, 2)
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
print(G.nodes())
print(G.edges())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]
# [(1, 2)]

# %%
G.add_edge(4, 5)

# %%
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5)])
print(G.edges())
# Out:
# [(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)]

# %%
G.add_edges_from([('Hi', 1), ('P', 1)])
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G = nx.path_graph(4)
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='green')

# %%
G = nx.Graph()
nx.add_path(G, [10, 11, 12, 13])
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='green')

# %%
print(G.degree(10))
print(G.degree([10, 11]))
# Out:
# 1
# [(10, 1), (11, 2)]

# %%
print(G.edges())
# Out:
# [(10, 11), (11, 12), (12, 13)]

# %%
G.remove_edge(11, 12)
print(G.edges())
# Out:
# [(10, 11), (12, 13)]

# %%
G.remove_edges_from([(10, 11), (12, 13)])
print(G.edges())
# Out:
# []

# %%
print(G.nodes())
# Out:
# [10, 11, 12, 13]

# %%
G.remove_node(12)

# %%
print(G.nodes())
# Out:
# [10, 11, 13]

# %%
G.remove_nodes_from([10, 11])
print(G.nodes())
# Out:
# [13]

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (2, 3), (3, 5)])

# %%
G.number_of_nodes()
# Out:
# 5

# %%
G.number_of_edges()
# Out:
# 5

# %%
G.remove_edge(1, 2)

# %%
G.number_of_edges()
# Out:
# 4

# %%
print(G.edges())
# Out:
# [(1, 3), (1, 4), (2, 3), (3, 5)]

# %%
G.remove_edge(1, 5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File F:\Anaconda\Lib\site-packages\networkx\classes\graph.py:1118, in Graph.remove_edge(self, u, v)
#    1117 try:
# -> 1118     del self._adj[u][v]
#    1119     if u != v:  # self-loop needs only one entry removed
#
# KeyError: 5
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 G.remove_edge(1, 5)
#
# File F:\Anaconda\Lib\site-packages\networkx\classes\graph.py:1122, in Graph.remove_edge(self, u, v)
#    1120         del self._adj[v][u]
#    1121 except KeyError as err:
# -> 1122     raise NetworkXError(f"The edge {u}-{v} is not in the graph") from err
#
# NetworkXError: The edge 1-5 is not in the graph

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (2, 3), (3, 5)])

# %%
G.add_edge(1, 5)

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 3), (1, 4), (1, 5), (2, 3), (3, 5)])

# %%
nx.draw(G, with_labels=True, node_color="lightblue", edge_color='red')

# %%
G.remove_node(3)
nx.draw(G, with_labels=True, node_color="lightblue", edge_color='red')

# %%
G.remove_nodes_from([1, 2])
nx.draw(G, with_labels=True, node_color="lightblue", edge_color='red')

# %%
print(G.number_of_nodes())
# Out:
# 3

# %%
import matplotlib.pyplot as plt

# %%
G = nx.erdos_renyi_graph(25, 0.2)

# %%
nx.draw(G)

# %%
G = nx.watts_strogatz_graph(50, 5, 0.2)
nx.draw(G)

# %%
G = nx.barabasi_albert_graph(25, 5)
nx.draw(G)

# %%
G = nx.random_lobster(25, 0.9, 0.9)
nx.draw(G)
