# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node(1)
print(G.nodes())
# Out:
# [1]

# %%
G.add_node('P')
G.add_node('Hi')
print(G.nodes())
# Out:
# [1, 'P', 'Hi']

# %%
G.add_nodes_from([2, 3])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3]

# %%
for node in G.nodes():
    print(node)
# Out:
# 1
# P
# Hi
# 2
# 3

# %%
G.add_nodes_from([3, 4])
print(G.nodes())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]

# %%
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G.add_edge(1, 2)
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
print(G.nodes())
print(G.edges())
# Out:
# [1, 'P', 'Hi', 2, 3, 4]
# [(1, 2)]

# %%
G.add_edge(4, 5)

# %%
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G.add_edges_from([(1, 2), (1, 3), (1, 4), (1, 5)])
print(G.edges())
# Out:
# [(1, 2), (1, 3), (1, 4), (1, 5), (4, 5)]

# %%
G.add_edges_from([('Hi', 1), ('P', 1)])
nx.draw(G, with_labels=True, node_color='lightblue')

# %%
G = nx.path_graph(4)
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='green')

# %%
G = nx.Graph()
nx.add_path(G, [10, 11, 12, 13])
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='green')

# %%
print(G.degree(10))
print(G.degree([10, 11]))
# Out:
# 1
# [(10, 1), (11, 2)]

# %%
print(G.edges())
# Out:
# [(10, 11), (11, 12), (12, 13)]

# %%
G.remove_edge(11, 12)
print(G.edges())
# Out:
# [(10, 11), (12, 13)]

# %%
G.remove_edges_from([(10, 11), (12, 13)])
print(G.edges())
# Out:
# []

# %%
print(G.nodes())
# Out:
# [10, 11, 12, 13]

# %%
G.remove_node(12)

# %%
print(G.nodes())
# Out:
# [10, 11, 13]

# %%
G.remove_nodes_from([10, 11])
print(G.nodes())
# Out:
# [13]

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (2, 3), (3, 5)])

# %%
G.number_of_nodes()
# Out:
# 5

# %%
G.number_of_edges()
# Out:
# 5

# %%
G.remove_edge(1, 2)

# %%
G.number_of_edges()
# Out:
# 4

# %%
print(G.edges())
# Out:
# [(1, 3), (1, 4), (2, 3), (3, 5)]

# %%
G = nx.Graph()
G.add_nodes_from([1, 2, 3, 4, 5])
G.add_edges_from([(1, 2), (1, 3), (1, 4), (2, 3), (3, 5)])

# %%
G.add_edge(1, 5)

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 3), (1, 4), (1, 5), (2, 3), (3, 5)])

# %%
nx.draw(G, with_labels=True, node_color="lightblue", edge_color='red')

# %%
G.remove_node(3)
nx.draw(G, with_labels=True, node_color="lightblue", edge_color='red')

# %%
G.remove_nodes_from([1, 2])
nx.draw(G, with_labels=True, node_color="lightblue", edge_color='red')

# %%
print(G.number_of_nodes())
# Out:
# 2

# %%
import matplotlib.pyplot as plt

# %%
G = nx.erdos_renyi_graph(25, 0.2)

# %%
nx.draw(G)

# %%
G = nx.watts_strogatz_graph(50, 5, 0.2)
nx.draw(G)

# %%
G = nx.barabasi_albert_graph(25, 5)
nx.draw(G)

# %%
G = nx.random_lobster(25, 0.9, 0.9)
nx.draw(G)

# %%
from scipy.stats import bernoulli

# %%
for i in range(6):
    print(bernoulli.rvs(p=0.2))
# Out:
# 0
# 0
# 0
# 1
# 0
# 0

# %%
def erdosGraph(N, p):
    G = nx.Graph()
    G.add_nodes_from(range(N))
    listG = list(G.nodes())
    for node1 in listG:
        for node2 in listG[node1 + 1:]:
            if (bernoulli.rvs(p = p)):
                G.add_edge(node1, node2)
    return G

nx.draw(erdosGraph(20, 0.18))

# %%
G1 = erdosGraph(80, 0.3)
print(G1.degree)
plt.hist(list([d for n, d in G1.degree()]), histtype='step')
# Out:
# [(0, 22), (1, 25), (2, 23), (3, 24), (4, 19), (5, 16), (6, 16), (7, 20), (8, 25), (9, 19), (10, 23), (11, 29), (12, 19), (13, 20), (14, 19), (15, 24), (16, 30), (17, 20), (18, 24), (19, 26), (20, 25), (21, 23), (22, 31), (23, 24), (24, 29), (25, 23), (26, 27), (27, 28), (28, 23), (29, 25), (30, 20), (31, 19), (32, 20), (33, 15), (34, 28), (35, 21), (36, 17), (37, 16), (38, 20), (39, 25), (40, 24), (41, 21), (42, 21), (43, 19), (44, 27), (45, 31), (46, 25), (47, 20), (48, 21), (49, 30), (50, 32), (51, 26), (52, 27), (53, 29), (54, 29), (55, 17), (56, 22), (57, 24), (58, 27), (59, 20), (60, 19), (61, 27), (62, 18), (63, 30), (64, 25), (65, 23), (66, 25), (67, 25), (68, 29), (69, 16), (70, 27), (71, 17), (72, 23), (73, 26), (74, 21), (75, 17), (76, 26), (77, 29), (78, 21), (79, 20)]
# (array([ 5.,  5., 16.,  6.,  9., 15.,  4.,  8.,  9.,  3.]),
#  array([15. , 16.7, 18.4, 20.1, 21.8, 23.5, 25.2, 26.9, 28.6, 30.3, 32. ]),
#  [<matplotlib.patches.Polygon at 0x23320e509b0>])

# %%
def pltGraph(G):
    plt.hist(list([d for _, d in G.degree()]), histtype='step')

G1 = erdosGraph(80, 0.3)
G2 = erdosGraph(80, 0.3)
G3 = erdosGraph(80, 0.3)
pltGraph(G1)
pltGraph(G2)
pltGraph(G3)

# %%
import numpy as np

# %%
K = np.loadtxt('test1.csv', delimiter=',')
G = nx.to_networkx_graph(K)
nx.draw(G, with_labels=True, node_color="yellow", edge_color="red")

# %%
G = nx.karate_club_graph()
nx.draw(G, with_labels=True, node_color="lightblue", edge_color="yellow")

# %%
G.degree()
# Out:
# DegreeView({0: 16, 1: 9, 2: 10, 3: 6, 4: 3, 5: 4, 6: 4, 7: 4, 8: 5, 9: 2, 10: 3, 11: 1, 12: 2, 13: 5, 14: 2, 15: 2, 16: 2, 17: 2, 18: 2, 19: 3, 20: 2, 21: 2, 22: 2, 23: 5, 24: 3, 25: 3, 26: 2, 27: 4, 28: 3, 29: 4, 30: 4, 31: 6, 32: 12, 33: 17})

# %%
print(G.degree())
# Out:
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]

# %%
print(G.degree(15))
# Out:
# 2

# %%
print(f'노드의 개수: {G.number_of_nodes()}')
print(f'엣지의 개수: {G.number_of_edges()}')
print(f'평균 차수: {np.mean([d for n, d in G.degree()]) : .1f}')
# Out:
# 노드의 개수: 34
# 엣지의 개수: 78
# 평균 차수:  4.6

# %%
plt.xlabel('Degree')
plt.ylabel('Prob. of node degree')
plt.hist(list([d for n, d in G.degree]), histtype='step')
# Out:
# (array([12., 12.,  3.,  2.,  0.,  2.,  1.,  0.,  0.,  2.]),
#  array([ 1. ,  2.6,  4.2,  5.8,  7.4,  9. , 10.6, 12.2, 13.8, 15.4, 17. ]),
#  [<matplotlib.patches.Polygon at 0x23322ca9a90>])

# %%
print(G.degree())
# Out:
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]

# %%
pos, degree = min([(n, d) for n, d in G.degree()], key = lambda x:x[1])

# %%
print(f'노드 : {pos}, 차수 : {degree}')
print(G.degree())
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='yellow')
# Out:
# 노드 : 11, 차수 : 1
# [(0, 16), (1, 9), (2, 10), (3, 6), (4, 3), (5, 4), (6, 4), (7, 4), (8, 5), (9, 2), (10, 3), (11, 1), (12, 2), (13, 5), (14, 2), (15, 2), (16, 2), (17, 2), (18, 2), (19, 3), (20, 2), (21, 2), (22, 2), (23, 5), (24, 3), (25, 3), (26, 2), (27, 4), (28, 3), (29, 4), (30, 4), (31, 6), (32, 12), (33, 17)]

# %%
nx.draw(G, with_labels=True, node_size = 100, node_color='lightblue', edge_color='yellow')

# %%
nx.draw(G, with_labels=True, node_size = [d*100 for n, d in G.degree()], node_color='lightblue', edge_color='yellow')

# %%
import zipfile

# %%
zf = zipfile.ZipFile('football.zip')
txt = zf.read('football.txt').decode()
gml = zf.read('football.gml').decode()
gml = gml.split('\n')[1:]
G = nx.parse_gml(gml)

# %%
print(gml)
# Out:
# ['graph', '[', '  directed 0', '  node', '  [', '    id 0', '    label "BrighamYoung"', '    value 7', '  ]', '  node', '  [', '    id 1', '    label "FloridaState"', '    value 0', '  ]', '  node', '  [', '    id 2', '    label "Iowa"', '    value 2', '  ]', '  node', '  [', '    id 3', '    label "KansasState"', '    value 3', '  ]', '  node', '  [', '    id 4', '    label "NewMexico"', '    value 7', '  ]', '  node', '  [', '    id 5', '    label "TexasTech"', '    value 3', '  ]', '  node', '  [', '    id 6', '    label "PennState"', '    value 2', '  ]', '  node', '  [', '    id 7', '    label "SouthernCalifornia"', '    value 8', '  ]', '  node', '  [', '    id 8', '    label "ArizonaState"', '    value 8', '  ]', '  node', '  [', '    id 9', '    label "SanDiegoState"', '    value 7', '  ]', '  node', '  [', '    id 10', '    label "Baylor"', '    value 3', '  ]', '  node', '  [', '    id 11', '    label "NorthTexas"', '    value 10', '  ]', '  node', '  [', '    id 12', '    
# ...

# %%
print(G.number_of_edges())
# Out:
# 613

# %%
nx.draw(G, with_labels=True, node_size=100, node_color='lightblue', edge_color='yellow')
plt.savefig('football.pdf')

# %%
print(f'No. of nodes : {G.number_of_nodes()}')
print(f'No. of edges: {G.number_of_edges()}')
print(f'Avg. of degrees: {np.mean([d for n, d in G.degree()]): .1f} ')
# Out:
# No. of nodes : 115
# No. of edges: 613
# Avg. of degrees:  10.7

# %%
import pandas as pd
